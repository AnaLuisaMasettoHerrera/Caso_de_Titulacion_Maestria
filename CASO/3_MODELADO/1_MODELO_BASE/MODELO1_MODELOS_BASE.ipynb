# %%
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_077c1e374ae94b51a0cb42ce18d9d709 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='VCQ0_K-wfx9BLqzaPAtCPnKUfcuaYVQCWYcEHtd9fzCl',
    ibm_auth_endpoint="https://iam.ng.bluemix.net/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')

body = client_077c1e374ae94b51a0cb42ce18d9d709.get_object(Bucket='modelostitulacion-donotdelete-pr-4wxwlfbb1ootwo',Key='DATOS_COMPLETOS_FINALES_TITULACION_PARA_MODELOS.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_1 = pd.read_csv(body)
df_data_1.head()
# Out:
#    tiendaID  marcaID  skuID  gammaID  fechaID  ventas_por_mes  \
# 0         1        2      1        1        0               0
# 1         1        2      1        1        1               0
# 2         1        2      1        1        2               0
# 3         1        2      1        1        3               0
# 4         1        2      1        1        4               0
#
#    variable_y_ventas_del_siguiente_mes  ventas_totales_por_tienda_por_mes  \
# 0                                  0.0                                 70
# 1                                  0.0                                 79
# 2                                  0.0                                 87
# 3                                  0.0                                 75
# 4                                  0.0                                 77
#
#    ventas_promedio_por_tienda_por_mes  ventas_totales_por_marca_por_mes  ...  \
# ...

# %%
df_data_1.shape
# Out:
# (8685950, 39)

# %%
#list(df_data_1.columns)

# %%
df_data = df_data_1.drop(['ventas_totales_por_tienda_por_mes',
 'ventas_promedio_por_tienda_por_mes',
 'ventas_totales_por_marca_por_mes',
 'ventas_promedio_por_marca_por_mes',
 'ventas_totales_por_gamma_por_mes',
 'ventas_promedio_por_gamma_por_mes',
 'ventas_totales_por_sku_por_mes',
 'ventas_promedio_por_sku_por_mes',
 'lag1mes_ventas_totales_por_tienda_por_mes',
 'lag1mes_ventas_promedio_por_tienda_por_mes',
 'lag1mes_ventas_totales_por_marca_por_mes',
 'lag1mes_entas_promedio_por_marca_por_mes',
 'lag1mes_ventas_totales_por_gamma_por_mes',
 'lag1mes_ventas_promedio_por_gamma_por_mes',
 'lag1mes_ventas_totales_por_sku_por_mes',
 'lag1mes_ventas_promedio_por_sku_por_mes',
 'lag2mes_ventas_totales_por_tienda_por_mes',
 'lag2mes_ventas_promedio_por_tienda_por_mes',
 'lag2mes_ventas_totales_por_marca_por_mes',
 'lag2mes_entas_promedio_por_marca_por_mes',
 'lag2mes_ventas_totales_por_gamma_por_mes',
 'lag2mes_ventas_promedio_por_gamma_por_mes',
 'lag2mes_ventas_totales_por_sku_por_mes',
 'lag2mes_ventas_promedio_por_sku_por_mes',
 'lag3mes_ventas_totales_por_tienda_por_mes',
 'lag3mes_ventas_promedio_por_tienda_por_mes',
 'lag3mes_ventas_totales_por_marca_por_mes',
 'lag3mes_entas_promedio_por_marca_por_mes',
 'lag3mes_ventas_totales_por_gamma_por_mes',
 'lag3mes_ventas_promedio_por_gamma_por_mes',
 'lag3mes_ventas_totales_por_sku_por_mes',
 'lag3mes_ventas_promedio_por_sku_por_mes'], axis=1)

# %%
df_data.head(20)
# Out:
#     tiendaID  marcaID  skuID  gammaID  fechaID  ventas_por_mes  \
# 0          1        2      1        1        0               0
# 1          1        2      1        1        1               0
# 2          1        2      1        1        2               0
# 3          1        2      1        1        3               0
# 4          1        2      1        1        4               0
# 5          1        2      1        1        5               0
# 6          1        2      1        1        6               0
# 7          1        2      1        1        7               0
# 8          1        2      1        1        8               0
# 9          1        2      1        1        9               0
# 10         2        2      1        1        0               0
# 11         2        2      1        1        1               0
# 12         2        2      1        1        2               0
# 13         2        2      1        1        3               0
# ...

# %% [markdown]
# Quitar todos los renglones que contengan el mes de marzo (9), esto se debe a que no se tiene información de las ventas que se hicieron en abril. (remover NA's)

# %%
df_data = df_data[df_data.fechaID != 9]

# %% [markdown]
# ## Predecir lo del mes pasado

# %%
#pedir lo del mes anteior
df_data['pedir_lo_del_mes_pasado'] = df_data.groupby(['tiendaID','marcaID','skuID','gammaID'])['ventas_por_mes'].shift(0)
df_data.head(5)
# Out:
#    tiendaID  marcaID  skuID  gammaID  fechaID  ventas_por_mes  \
# 0         1        2      1        1        0               0
# 1         1        2      1        1        1               0
# 2         1        2      1        1        2               0
# 3         1        2      1        1        3               0
# 4         1        2      1        1        4               0
#
#    variable_y_ventas_del_siguiente_mes  pedir_lo_del_mes_pasado
# 0                                  0.0                        0
# 1                                  0.0                        0
# 2                                  0.0                        0
# 3                                  0.0                        0
# 4                                  0.0                        0

# %% [markdown]
# ## Predecir el promedio de los dos meses anteriores
# ### Junio -
# ### Julio - cuanto voy a pedir para agosto

# %%
#promedio de los dos meses anteriores 
df_data['promedio_de_dos_meses_anteriores'] = df_data.groupby(['tiendaID','marcaID','skuID','gammaID'])['ventas_por_mes'].apply(lambda x:x.rolling(center=False,window=2).mean())
df_data.head(5)
# Out:
#    tiendaID  marcaID  skuID  gammaID  fechaID  ventas_por_mes  \
# 0         1        2      1        1        0               0
# 1         1        2      1        1        1               0
# 2         1        2      1        1        2               0
# 3         1        2      1        1        3               0
# 4         1        2      1        1        4               0
#
#    variable_y_ventas_del_siguiente_mes  pedir_lo_del_mes_pasado  \
# 0                                  0.0                        0
# 1                                  0.0                        0
# 2                                  0.0                        0
# 3                                  0.0                        0
# 4                                  0.0                        0
#
#    promedio_de_dos_meses_anteriores
# 0                               NaN
# 1                               0.0
# 2                               0.0
# 3                               0.0
# ...

# %% [markdown]
# ## Predecir el promedio de los tres meses anteriores
# ### Junio -
# ### Julio
# ### Agosto - cuanto voy a pedir para septiembre

# %%
#promedio de los tres meses anteriores 
df_data['promedio_de_tres_meses_anteriores'] = df_data.groupby(['tiendaID','marcaID','skuID','gammaID'])['ventas_por_mes'].apply(lambda x:x.rolling(center=False,window=3).mean())
df_data.head(5)
# Out:
#    tiendaID  marcaID  skuID  gammaID  fechaID  ventas_por_mes  \
# 0         1        2      1        1        0               0
# 1         1        2      1        1        1               0
# 2         1        2      1        1        2               0
# 3         1        2      1        1        3               0
# 4         1        2      1        1        4               0
#
#    variable_y_ventas_del_siguiente_mes  pedir_lo_del_mes_pasado  \
# 0                                  0.0                        0
# 1                                  0.0                        0
# 2                                  0.0                        0
# 3                                  0.0                        0
# 4                                  0.0                        0
#
#    promedio_de_dos_meses_anteriores  promedio_de_tres_meses_anteriores
# 0                               NaN                                NaN
# ...

# %% [markdown]
# ## Predecir el promedio de los cuatro meses anteriores
# ### Junio -
# ### Julio
# ### Agosto
# ### Septiembre - cuanto voy a pedir para octubre

# %%
#promedio de los cuatro meses anteriores
df_data['promedio_de_cuatro_meses_anteriores'] = df_data.groupby(['tiendaID','marcaID','skuID','gammaID'])['ventas_por_mes'].apply(lambda x:x.rolling(center=False,window=4).mean())
df_data.head(5)
# Out:
#    tiendaID  marcaID  skuID  gammaID  fechaID  ventas_por_mes  \
# 0         1        2      1        1        0               0
# 1         1        2      1        1        1               0
# 2         1        2      1        1        2               0
# 3         1        2      1        1        3               0
# 4         1        2      1        1        4               0
#
#    variable_y_ventas_del_siguiente_mes  pedir_lo_del_mes_pasado  \
# 0                                  0.0                        0
# 1                                  0.0                        0
# 2                                  0.0                        0
# 3                                  0.0                        0
# 4                                  0.0                        0
#
#    promedio_de_dos_meses_anteriores  promedio_de_tres_meses_anteriores  \
# 0                               NaN                                NaN
# ...

# %% [markdown]
# ### División Mensual del datafram con preddiciones

# %%
df_error_julio = df_data[df_data.fechaID == 0]
df_error_julio.head(5)
# Out:
#     tiendaID  marcaID  skuID  gammaID  fechaID  ventas_por_mes  \
# 0          1        2      1        1        0               0
# 10         2        2      1        1        0               0
# 20         3        2      1        1        0               0
# 30         4        2      1        1        0               0
# 40         5        2      1        1        0               0
#
#     variable_y_ventas_del_siguiente_mes  pedir_lo_del_mes_pasado  \
# 0                                   0.0                        0
# 10                                  0.0                        0
# 20                                  0.0                        0
# 30                                  0.0                        0
# 40                                  0.0                        0
#
#     promedio_de_dos_meses_anteriores  promedio_de_tres_meses_anteriores  \
# 0                                NaN                                NaN
# ...

# %%
df_error_julio.shape
# Out:
# (868595, 11)

# %%
df_error_agosto = df_data[df_data.fechaID == 1]

# %%
df_error_septiembre = df_data[df_data.fechaID == 2]

# %%
df_error_octubre = df_data[df_data.fechaID == 3]

# %%
df_error_noviembre = df_data[df_data.fechaID == 4]

# %%
df_error_diciembre = df_data[df_data.fechaID == 5]

# %%
df_error_enero = df_data[df_data.fechaID == 6]

# %%
df_error_febrero = df_data[df_data.fechaID == 7]

# %%
df_error_marzo = df_data[df_data.fechaID == 8]
df_error_marzo.head(5)
# Out:
#     tiendaID  marcaID  skuID  gammaID  fechaID  ventas_por_mes  \
# 8          1        2      1        1        8               0
# 18         2        2      1        1        8               0
# 28         3        2      1        1        8               0
# 38         4        2      1        1        8               0
# 48         5        2      1        1        8               0
#
#     variable_y_ventas_del_siguiente_mes  pedir_lo_del_mes_pasado  \
# 8                                   0.0                        0
# 18                                  0.0                        0
# 28                                  0.0                        0
# 38                                  0.0                        0
# 48                                  0.0                        0
#
#     promedio_de_dos_meses_anteriores  promedio_de_tres_meses_anteriores  \
# 8                                0.0                                0.0
# ...

# %%
df_error_marzo.shape
# Out:
# (868595, 11)

# %% [markdown]
# ### Cálculo de errores por modelo y por mes

# %% [markdown]
# #### Pedir lo anterior:

# %%
MSE_julio_m1 = sum((df_error_julio['variable_y_ventas_del_siguiente_mes'] - df_error_julio['pedir_lo_del_mes_pasado']) ** 2)/868595
MSE_agosto_m1 = sum((df_error_agosto['variable_y_ventas_del_siguiente_mes'] - df_error_agosto['pedir_lo_del_mes_pasado']) ** 2)/868595
MSE_septiembre_m1 = sum((df_error_septiembre['variable_y_ventas_del_siguiente_mes'] - df_error_septiembre['pedir_lo_del_mes_pasado']) ** 2)/868595
MSE_octubre_m1 = sum((df_error_octubre['variable_y_ventas_del_siguiente_mes'] - df_error_octubre['pedir_lo_del_mes_pasado']) ** 2)/868595
MSE_noviembre_m1 = sum((df_error_noviembre['variable_y_ventas_del_siguiente_mes'] - df_error_noviembre['pedir_lo_del_mes_pasado']) ** 2)/868595
MSE_diciembre_m1 = sum((df_error_diciembre['variable_y_ventas_del_siguiente_mes'] - df_error_diciembre['pedir_lo_del_mes_pasado']) ** 2)/868595
MSE_enero_m1 = sum((df_error_enero['variable_y_ventas_del_siguiente_mes'] - df_error_enero['pedir_lo_del_mes_pasado']) ** 2)/868595
MSE_febrero_m1 = sum((df_error_febrero['variable_y_ventas_del_siguiente_mes'] - df_error_febrero['pedir_lo_del_mes_pasado']) ** 2)/868595
MSE_marzo_m1 = sum((df_error_marzo['variable_y_ventas_del_siguiente_mes'] - df_error_marzo['pedir_lo_del_mes_pasado']) ** 2)/868595

# %%
RMSE_julio_m1 = MSE_julio_m1 ** (1/2)
RMSE_agosto_m1 = MSE_agosto_m1 ** (1/2)
RMSE_septiembre_m1 = MSE_septiembre_m1 ** (1/2)
RMSE_octubre_m1 = MSE_octubre_m1 ** (1/2)
RMSE_noviembre_m1 = MSE_noviembre_m1 ** (1/2)
RMSE_diciembre_m1 = MSE_diciembre_m1 ** (1/2)
RMSE_enero_m1 = MSE_enero_m1 ** (1/2)
RMSE_febrero_m1 = MSE_febrero_m1 ** (1/2)
RMSE_marzo_m1 = MSE_marzo_m1 ** (1/2)

# %%
MAE_julio_m1 = sum(abs(df_error_julio['variable_y_ventas_del_siguiente_mes'] - df_error_julio['pedir_lo_del_mes_pasado']))/868595
MAE_agosto_m1 = sum(abs(df_error_agosto['variable_y_ventas_del_siguiente_mes'] - df_error_agosto['pedir_lo_del_mes_pasado']))/868595
MAE_septiembre_m1 = sum(abs(df_error_septiembre['variable_y_ventas_del_siguiente_mes'] - df_error_septiembre['pedir_lo_del_mes_pasado']))/868595
MAE_octubre_m1 = sum(abs(df_error_octubre['variable_y_ventas_del_siguiente_mes'] - df_error_octubre['pedir_lo_del_mes_pasado']))/868595
MAE_noviembre_m1 = sum(abs(df_error_noviembre['variable_y_ventas_del_siguiente_mes'] - df_error_noviembre['pedir_lo_del_mes_pasado']))/868595
MAE_diciembre_m1 = sum(abs(df_error_diciembre['variable_y_ventas_del_siguiente_mes'] - df_error_diciembre['pedir_lo_del_mes_pasado']))/868595
MAE_enero_m1 = sum(abs(df_error_enero['variable_y_ventas_del_siguiente_mes'] - df_error_enero['pedir_lo_del_mes_pasado']))/868595
MAE_febrero_m1 = sum(abs(df_error_febrero['variable_y_ventas_del_siguiente_mes'] - df_error_febrero['pedir_lo_del_mes_pasado']))/868595
MAE_marzo_m1 = sum(abs(df_error_marzo['variable_y_ventas_del_siguiente_mes'] - df_error_marzo['pedir_lo_del_mes_pasado']))/868595

# %%
errores_m1=[['mse_pedir_anterior',MSE_julio_m1,MSE_agosto_m1,MSE_septiembre_m1, MSE_octubre_m1, MSE_noviembre_m1, MSE_diciembre_m1, MSE_enero_m1, MSE_febrero_m1,MSE_marzo_m1],
       ['rmse_pedir_anterior',RMSE_julio_m1,RMSE_agosto_m1,RMSE_septiembre_m1, RMSE_octubre_m1, RMSE_noviembre_m1, RMSE_diciembre_m1, RMSE_enero_m1, RMSE_febrero_m1,RMSE_marzo_m1],
       ['mae_pedir_anterior',MAE_julio_m1,MAE_agosto_m1,MAE_septiembre_m1, MAE_octubre_m1, MAE_noviembre_m1, MAE_diciembre_m1, MAE_enero_m1, MAE_febrero_m1,RMSE_marzo_m1]]
errores_m1= pd.DataFrame(errores_m1,columns = ['Modelo', 'Error Julio 2018','Error Agosto 2018','Error Septiembre 2018', 'Error Octubre 2018','Error Noviembre 2018', 'Error Diciembre 2018','Error Enero 2019','Error Febrero 2019','Error Marzo 2019'])
errores_m1
# Out:
#                 Modelo  Error Julio 2018  Error Agosto 2018  \
# 0   mse_pedir_anterior          0.568659           0.515156
# 1  rmse_pedir_anterior          0.754095           0.717744
# 2   mae_pedir_anterior          0.138108           0.135469
#
#    Error Septiembre 2018  Error Octubre 2018  Error Noviembre 2018  \
# 0               0.392803            0.489997              0.579640
# 1               0.626740            0.699998              0.761341
# 2               0.119700            0.130119              0.148145
#
#    Error Diciembre 2018  Error Enero 2019  Error Febrero 2019  \
# 0              0.770711          0.696396            0.441374
# 1              0.877902          0.834503            0.664360
# 2              0.177139          0.161523            0.122208
#
#    Error Marzo 2019
# 0          0.448506
# 1          0.669706
# 2          0.669706

# %% [markdown]
# #### Modelo 2: Promedio de dos meses anteriores

# %%
MSE_julio_m2 = None
MSE_agosto_m2 = sum((df_error_agosto['variable_y_ventas_del_siguiente_mes'] - df_error_agosto['promedio_de_dos_meses_anteriores']) ** 2)/868595
MSE_septiembre_m2 = sum((df_error_septiembre['variable_y_ventas_del_siguiente_mes'] - df_error_septiembre['promedio_de_dos_meses_anteriores']) ** 2)/868595
MSE_octubre_m2 = sum((df_error_octubre['variable_y_ventas_del_siguiente_mes'] - df_error_octubre['promedio_de_dos_meses_anteriores']) ** 2)/868595
MSE_noviembre_m2 = sum((df_error_noviembre['variable_y_ventas_del_siguiente_mes'] - df_error_noviembre['promedio_de_dos_meses_anteriores']) ** 2)/868595
MSE_diciembre_m2 = sum((df_error_diciembre['variable_y_ventas_del_siguiente_mes'] - df_error_diciembre['promedio_de_dos_meses_anteriores']) ** 2)/868595
MSE_enero_m2 = sum((df_error_enero['variable_y_ventas_del_siguiente_mes'] - df_error_enero['promedio_de_dos_meses_anteriores']) ** 2)/868595
MSE_febrero_m2 = sum((df_error_febrero['variable_y_ventas_del_siguiente_mes'] - df_error_febrero['promedio_de_dos_meses_anteriores']) ** 2)/868595
MSE_marzo_m2 = sum((df_error_marzo['variable_y_ventas_del_siguiente_mes'] - df_error_marzo['promedio_de_dos_meses_anteriores']) ** 2)/868595

# %%
RMSE_julio_m2 = None
RMSE_agosto_m2 = MSE_agosto_m2 ** (1/2)
RMSE_septiembre_m2 = MSE_septiembre_m2 ** (1/2)
RMSE_octubre_m2 = MSE_octubre_m2 ** (1/2)
RMSE_noviembre_m2 = MSE_noviembre_m2 ** (1/2)
RMSE_diciembre_m2 = MSE_diciembre_m2 ** (1/2)
RMSE_enero_m2 = MSE_enero_m2 ** (1/2)
RMSE_febrero_m2 = MSE_febrero_m2 ** (1/2)
RMSE_marzo_m2 = MSE_marzo_m2 ** (1/2)

# %%
MAE_julio_m2 = None
MAE_agosto_m2 = sum(abs(df_error_agosto['variable_y_ventas_del_siguiente_mes'] - df_error_agosto['promedio_de_dos_meses_anteriores']))/868595
MAE_septiembre_m2 = sum(abs(df_error_septiembre['variable_y_ventas_del_siguiente_mes'] - df_error_septiembre['promedio_de_dos_meses_anteriores']))/868595
MAE_octubre_m2 = sum(abs(df_error_octubre['variable_y_ventas_del_siguiente_mes'] - df_error_octubre['promedio_de_dos_meses_anteriores']))/868595
MAE_noviembre_m2 = sum(abs(df_error_noviembre['variable_y_ventas_del_siguiente_mes'] - df_error_noviembre['promedio_de_dos_meses_anteriores']))/868595
MAE_diciembre_m2 = sum(abs(df_error_diciembre['variable_y_ventas_del_siguiente_mes'] - df_error_diciembre['promedio_de_dos_meses_anteriores']))/868595
MAE_enero_m2 = sum(abs(df_error_enero['variable_y_ventas_del_siguiente_mes'] - df_error_enero['promedio_de_dos_meses_anteriores']))/868595
MAE_febrero_m2 = sum(abs(df_error_febrero['variable_y_ventas_del_siguiente_mes'] - df_error_febrero['promedio_de_dos_meses_anteriores']))/868595
MAE_marzo_m2 = sum(abs(df_error_marzo['variable_y_ventas_del_siguiente_mes'] - df_error_marzo['promedio_de_dos_meses_anteriores']))/868595

# %%
errores_m2=[['mse_promedio_2_meses_anteriores',MSE_julio_m2,MSE_agosto_m2,MSE_septiembre_m2, MSE_octubre_m2, MSE_noviembre_m2, MSE_diciembre_m2, MSE_enero_m2, MSE_febrero_m2,MSE_marzo_m2],
       ['rmse_promedio_2_meses_anteriores',RMSE_julio_m2,RMSE_agosto_m2,RMSE_septiembre_m2, RMSE_octubre_m2, RMSE_noviembre_m2, RMSE_diciembre_m2, RMSE_enero_m2, RMSE_febrero_m2,RMSE_marzo_m2],
       ['mae_promedio_2_meses_anteriores',MAE_julio_m2,MAE_agosto_m2,MAE_septiembre_m2, MAE_octubre_m2, MAE_noviembre_m2, MAE_diciembre_m2, MAE_enero_m2, MAE_febrero_m2,RMSE_marzo_m2]]
errores_m2= pd.DataFrame(errores_m2,columns = ['Modelo', 'Error Julio 2018','Error Agosto 2018','Error Septiembre 2018', 'Error Octubre 2018','Error Noviembre 2018', 'Error Diciembre 2018','Error Enero 2019','Error Febrero 2019','Error Marzo 2019'])
errores_m2
# Out:
#                              Modelo Error Julio 2018  Error Agosto 2018  \
# 0   mse_promedio_2_meses_anteriores             None           0.551698
# 1  rmse_promedio_2_meses_anteriores             None           0.742764
# 2   mae_promedio_2_meses_anteriores             None           0.140563
#
#    Error Septiembre 2018  Error Octubre 2018  Error Noviembre 2018  \
# 0               0.364511            0.517241              0.525178
# 1               0.603748            0.719195              0.724692
# 2               0.125616            0.138270              0.145481
#
#    Error Diciembre 2018  Error Enero 2019  Error Febrero 2019  \
# 0              0.651252          0.552302            0.510564
# 1              0.807002          0.743170            0.714538
# 2              0.168484          0.158390            0.143794
#
#    Error Marzo 2019
# 0          0.361328
# 1          0.601106
# 2          0.601106

# %% [markdown]
# #### Modelo 3: Promedio de 3 meses anteriores

# %%
MSE_julio_m3 = None
MSE_agosto_m3 = None
MSE_septiembre_m3 = sum((df_error_septiembre['variable_y_ventas_del_siguiente_mes'] - df_error_septiembre['promedio_de_tres_meses_anteriores']) ** 2)/868595
MSE_octubre_m3 = sum((df_error_octubre['variable_y_ventas_del_siguiente_mes'] - df_error_octubre['promedio_de_tres_meses_anteriores']) ** 2)/868595
MSE_noviembre_m3 = sum((df_error_noviembre['variable_y_ventas_del_siguiente_mes'] - df_error_noviembre['promedio_de_tres_meses_anteriores']) ** 2)/868595
MSE_diciembre_m3 = sum((df_error_diciembre['variable_y_ventas_del_siguiente_mes'] - df_error_diciembre['promedio_de_tres_meses_anteriores']) ** 2)/868595
MSE_enero_m3 = sum((df_error_enero['variable_y_ventas_del_siguiente_mes'] - df_error_enero['promedio_de_tres_meses_anteriores']) ** 2)/868595
MSE_febrero_m3 = sum((df_error_febrero['variable_y_ventas_del_siguiente_mes'] - df_error_febrero['promedio_de_tres_meses_anteriores']) ** 2)/868595
MSE_marzo_m3 = sum((df_error_marzo['variable_y_ventas_del_siguiente_mes'] - df_error_marzo['promedio_de_tres_meses_anteriores']) ** 2)/868595

# %%
RMSE_julio_m3 = None
RMSE_agosto_m3 = None
RMSE_septiembre_m3 = MSE_septiembre_m3 ** (1/2)
RMSE_octubre_m3 = MSE_octubre_m3 ** (1/2)
RMSE_noviembre_m3 = MSE_noviembre_m3 ** (1/2)
RMSE_diciembre_m3 = MSE_diciembre_m3 ** (1/2)
RMSE_enero_m3 = MSE_enero_m3 ** (1/2)
RMSE_febrero_m3 = MSE_febrero_m3 ** (1/2)
RMSE_marzo_m3 = MSE_marzo_m3 ** (1/2)

# %%
MAE_julio_m3 = None
MAE_agosto_m3 = None
MAE_septiembre_m3 = sum(abs(df_error_septiembre['variable_y_ventas_del_siguiente_mes'] - df_error_septiembre['promedio_de_tres_meses_anteriores']))/868595
MAE_octubre_m3 = sum(abs(df_error_octubre['variable_y_ventas_del_siguiente_mes'] - df_error_octubre['promedio_de_tres_meses_anteriores']))/868595
MAE_noviembre_m3 = sum(abs(df_error_noviembre['variable_y_ventas_del_siguiente_mes'] - df_error_noviembre['promedio_de_tres_meses_anteriores']))/868595
MAE_diciembre_m3 = sum(abs(df_error_diciembre['variable_y_ventas_del_siguiente_mes'] - df_error_diciembre['promedio_de_tres_meses_anteriores']))/868595
MAE_enero_m3 = sum(abs(df_error_enero['variable_y_ventas_del_siguiente_mes'] - df_error_enero['promedio_de_tres_meses_anteriores']))/868595
MAE_febrero_m3 = sum(abs(df_error_febrero['variable_y_ventas_del_siguiente_mes'] - df_error_febrero['promedio_de_tres_meses_anteriores']))/868595
MAE_marzo_m3 = sum(abs(df_error_marzo['variable_y_ventas_del_siguiente_mes'] - df_error_marzo['promedio_de_tres_meses_anteriores']))/868595

# %%
errores_m3=[['mse_promedio_3_meses_anteriores',MSE_julio_m3,MSE_agosto_m3,MSE_septiembre_m3, MSE_octubre_m3, MSE_noviembre_m3, MSE_diciembre_m3, MSE_enero_m3, MSE_febrero_m3,MSE_marzo_m3],
       ['rmse_promedio_3_meses_anteriores',RMSE_julio_m3,RMSE_agosto_m3,RMSE_septiembre_m3, RMSE_octubre_m3, RMSE_noviembre_m3, RMSE_diciembre_m3, RMSE_enero_m3, RMSE_febrero_m3,RMSE_marzo_m3],
       ['mae_promedio_3_meses_anteriores',MAE_julio_m3,MAE_agosto_m3,MAE_septiembre_m3, MAE_octubre_m3, MAE_noviembre_m3, MAE_diciembre_m3, MAE_enero_m3, MAE_febrero_m3,RMSE_marzo_m3]]
errores_m3= pd.DataFrame(errores_m3,columns = ['Modelo', 'Error Julio 2018','Error Agosto 2018','Error Septiembre 2018', 'Error Octubre 2018','Error Noviembre 2018', 'Error Diciembre 2018','Error Enero 2019','Error Febrero 2019','Error Marzo 2019'])
errores_m3
# Out:
#                              Modelo Error Julio 2018 Error Agosto 2018  \
# 0   mse_promedio_3_meses_anteriores             None              None
# 1  rmse_promedio_3_meses_anteriores             None              None
# 2   mae_promedio_3_meses_anteriores             None              None
#
#    Error Septiembre 2018  Error Octubre 2018  Error Noviembre 2018  \
# 0               0.402212            0.536268              0.559514
# 1               0.634202            0.732303              0.748007
# 2               0.132810            0.147070              0.152375
#
#    Error Diciembre 2018  Error Enero 2019  Error Febrero 2019  \
# 0              0.642701          0.490568            0.530056
# 1              0.801686          0.700405            0.728049
# 2              0.168346          0.152440            0.153275
#
#    Error Marzo 2019
# 0          0.393788
# 1          0.627526
# 2          0.627526

# %% [markdown]
# #### Modelo 4: Promedio de 4 meses anteriores

# %%
MSE_julio_m4 = None
MSE_agosto_m4 = None
MSE_septiembre_m4 = None
MSE_octubre_m4 = sum((df_error_octubre['variable_y_ventas_del_siguiente_mes'] - df_error_octubre['promedio_de_cuatro_meses_anteriores']) ** 2)/868595
MSE_noviembre_m4 = sum((df_error_noviembre['variable_y_ventas_del_siguiente_mes'] - df_error_noviembre['promedio_de_cuatro_meses_anteriores']) ** 2)/868595
MSE_diciembre_m4 = sum((df_error_diciembre['variable_y_ventas_del_siguiente_mes'] - df_error_diciembre['promedio_de_cuatro_meses_anteriores']) ** 2)/868595
MSE_enero_m4 = sum((df_error_enero['variable_y_ventas_del_siguiente_mes'] - df_error_enero['promedio_de_cuatro_meses_anteriores']) ** 2)/868595
MSE_febrero_m4 = sum((df_error_febrero['variable_y_ventas_del_siguiente_mes'] - df_error_febrero['promedio_de_cuatro_meses_anteriores']) ** 2)/868595
MSE_marzo_m4 = sum((df_error_marzo['variable_y_ventas_del_siguiente_mes'] - df_error_marzo['promedio_de_cuatro_meses_anteriores']) ** 2)/868595

# %%
RMSE_julio_m4 = None
RMSE_agosto_m4 = None
RMSE_septiembre_m4 = None
RMSE_octubre_m4 = MSE_octubre_m4 ** (1/2)
RMSE_noviembre_m4 = MSE_noviembre_m4 ** (1/2)
RMSE_diciembre_m4 = MSE_diciembre_m4 ** (1/2)
RMSE_enero_m4 = MSE_enero_m4 ** (1/2)
RMSE_febrero_m4 = MSE_febrero_m4 ** (1/2)
RMSE_marzo_m4 = MSE_marzo_m4 ** (1/2)

# %%
MAE_julio_m4 = None
MAE_agosto_m4 = None
MAE_septiembre_m4 = None
MAE_octubre_m4 = sum(abs(df_error_octubre['variable_y_ventas_del_siguiente_mes'] - df_error_octubre['promedio_de_cuatro_meses_anteriores']))/868595
MAE_noviembre_m4 = sum(abs(df_error_noviembre['variable_y_ventas_del_siguiente_mes'] - df_error_noviembre['promedio_de_cuatro_meses_anteriores']))/868595
MAE_diciembre_m4 = sum(abs(df_error_diciembre['variable_y_ventas_del_siguiente_mes'] - df_error_diciembre['promedio_de_cuatro_meses_anteriores']))/868595
MAE_enero_m4 = sum(abs(df_error_enero['variable_y_ventas_del_siguiente_mes'] - df_error_enero['promedio_de_cuatro_meses_anteriores']))/868595
MAE_febrero_m4 = sum(abs(df_error_febrero['variable_y_ventas_del_siguiente_mes'] - df_error_febrero['promedio_de_cuatro_meses_anteriores']))/868595
MAE_marzo_m4 = sum(abs(df_error_marzo['variable_y_ventas_del_siguiente_mes'] - df_error_marzo['promedio_de_cuatro_meses_anteriores']))/868595

# %%
errores_m4=[['mse_promedio_4_meses_anteriores',MSE_julio_m4,MSE_agosto_m4,MSE_septiembre_m4, MSE_octubre_m4, MSE_noviembre_m4, MSE_diciembre_m4, MSE_enero_m4, MSE_febrero_m4,MSE_marzo_m4],
       ['rmse_promedio_4_meses_anteriores',RMSE_julio_m4,RMSE_agosto_m4,RMSE_septiembre_m4, RMSE_octubre_m4, RMSE_noviembre_m4, RMSE_diciembre_m4, RMSE_enero_m4, RMSE_febrero_m4,RMSE_marzo_m4],
       ['mae_promedio_4_meses_anteriores',MAE_julio_m4,MAE_agosto_m4,MAE_septiembre_m4, MAE_octubre_m4, MAE_noviembre_m4, MAE_diciembre_m4, MAE_enero_m4, MAE_febrero_m4,RMSE_marzo_m4]]
errores_m4= pd.DataFrame(errores_m4,columns = ['Modelo', 'Error Julio 2018','Error Agosto 2018','Error Septiembre 2018', 'Error Octubre 2018','Error Noviembre 2018', 'Error Diciembre 2018','Error Enero 2019','Error Febrero 2019','Error Marzo 2019'])
errores_m4
# Out:
#                              Modelo Error Julio 2018 Error Agosto 2018  \
# 0   mse_promedio_4_meses_anteriores             None              None
# 1  rmse_promedio_4_meses_anteriores             None              None
# 2   mae_promedio_4_meses_anteriores             None              None
#
#   Error Septiembre 2018  Error Octubre 2018  Error Noviembre 2018  \
# 0                  None            0.555590              0.597967
# 1                  None            0.745379              0.773283
# 2                  None            0.152811              0.161652
#
#    Error Diciembre 2018  Error Enero 2019  Error Febrero 2019  \
# 0              0.684214          0.479182            0.518963
# 1              0.827172          0.692230            0.720391
# 2              0.174651          0.152000            0.152735
#
#    Error Marzo 2019
# 0          0.397311
# 1          0.630326
# 2          0.630326

# %% [markdown]
# ### Errores por métrica

# %% [markdown]
# #### MSE

# %%
MSE = [['mse_pedir_anterior',MSE_julio_m1,MSE_agosto_m1,MSE_septiembre_m1, MSE_octubre_m1, MSE_noviembre_m1, MSE_diciembre_m1, MSE_enero_m1, MSE_febrero_m1,MSE_marzo_m1],
       ['mse_promedio_2_meses_anteriores',MSE_julio_m2,MSE_agosto_m2,MSE_septiembre_m2, MSE_octubre_m2, MSE_noviembre_m2, MSE_diciembre_m2, MSE_enero_m2, MSE_febrero_m2,MSE_marzo_m2],
       ['mse_promedio_3_meses_anteriores',MSE_julio_m3,MSE_agosto_m3,MSE_septiembre_m3, MSE_octubre_m3, MSE_noviembre_m3, MSE_diciembre_m3, MSE_enero_m3, MSE_febrero_m3,MSE_marzo_m3],
       ['mse_promedio_4_meses_anteriores',MSE_julio_m4,MSE_agosto_m4,MSE_septiembre_m4, MSE_octubre_m4, MSE_noviembre_m4, MSE_diciembre_m4, MSE_enero_m4, MSE_febrero_m4,MSE_marzo_m4]]
errores_mse= pd.DataFrame(MSE,columns = ['Modelo', 'Error Julio 2018','Error Agosto 2018','Error Septiembre 2018', 'Error Octubre 2018','Error Noviembre 2018', 'Error Diciembre 2018','Error Enero 2019','Error Febrero 2019','Error Marzo 2019'])
errores_mse
# Out:
#                             Modelo  Error Julio 2018  Error Agosto 2018  \
# 0               mse_pedir_anterior          0.568659           0.515156
# 1  mse_promedio_2_meses_anteriores               NaN           0.551698
# 2  mse_promedio_3_meses_anteriores               NaN                NaN
# 3  mse_promedio_4_meses_anteriores               NaN                NaN
#
#    Error Septiembre 2018  Error Octubre 2018  Error Noviembre 2018  \
# 0               0.392803            0.489997              0.579640
# 1               0.364511            0.517241              0.525178
# 2               0.402212            0.536268              0.559514
# 3                    NaN            0.555590              0.597967
#
#    Error Diciembre 2018  Error Enero 2019  Error Febrero 2019  \
# 0              0.770711          0.696396            0.441374
# 1              0.651252          0.552302            0.510564
# 2              0.642701          0.490568            0.530056
# ...

# %% [markdown]
# #### RMSE

# %%
RMSE = [['rmse_pedir_anterior',RMSE_julio_m1,RMSE_agosto_m1,RMSE_septiembre_m1, RMSE_octubre_m1, RMSE_noviembre_m1, RMSE_diciembre_m1, RMSE_enero_m1, RMSE_febrero_m1,RMSE_marzo_m1],
       ['rmse_promedio_2_meses_anteriores',RMSE_julio_m2,RMSE_agosto_m2,RMSE_septiembre_m2, RMSE_octubre_m2, RMSE_noviembre_m2, RMSE_diciembre_m2, RMSE_enero_m2, RMSE_febrero_m2,RMSE_marzo_m2],
       ['rmse_promedio_3_meses_anteriores',RMSE_julio_m3,RMSE_agosto_m3,RMSE_septiembre_m3, RMSE_octubre_m3, RMSE_noviembre_m3, RMSE_diciembre_m3, RMSE_enero_m3, RMSE_febrero_m3,RMSE_marzo_m3],
       ['rmse_promedio_4_meses_anteriores',RMSE_julio_m4,RMSE_agosto_m4,RMSE_septiembre_m4, RMSE_octubre_m4, RMSE_noviembre_m4, RMSE_diciembre_m4, RMSE_enero_m4, RMSE_febrero_m4,RMSE_marzo_m4]]
errores_rmse= pd.DataFrame(RMSE,columns = ['Modelo', 'Error Julio 2018','Error Agosto 2018','Error Septiembre 2018', 'Error Octubre 2018','Error Noviembre 2018', 'Error Diciembre 2018','Error Enero 2019','Error Febrero 2019','Error Marzo 2019'])
errores_rmse
# Out:
#                              Modelo  Error Julio 2018  Error Agosto 2018  \
# 0               rmse_pedir_anterior          0.754095           0.717744
# 1  rmse_promedio_2_meses_anteriores               NaN           0.742764
# 2  rmse_promedio_3_meses_anteriores               NaN                NaN
# 3  rmse_promedio_4_meses_anteriores               NaN                NaN
#
#    Error Septiembre 2018  Error Octubre 2018  Error Noviembre 2018  \
# 0               0.626740            0.699998              0.761341
# 1               0.603748            0.719195              0.724692
# 2               0.634202            0.732303              0.748007
# 3                    NaN            0.745379              0.773283
#
#    Error Diciembre 2018  Error Enero 2019  Error Febrero 2019  \
# 0              0.877902          0.834503            0.664360
# 1              0.807002          0.743170            0.714538
# 2              0.801686          0.700405            0.728049
# ...

# %% [markdown]
# #### MAE

# %%
MAE = [['mae_pedir_anterior',MAE_julio_m1,MAE_agosto_m1,MAE_septiembre_m1, MAE_octubre_m1, MAE_noviembre_m1, MAE_diciembre_m1, MAE_enero_m1, MAE_febrero_m1,MAE_marzo_m1],
       ['mae_promedio_2_meses_anteriores',MAE_julio_m2,MAE_agosto_m2,MAE_septiembre_m2, MAE_octubre_m2, MAE_noviembre_m2, MAE_diciembre_m2, MAE_enero_m2, MAE_febrero_m2,MAE_marzo_m2],
       ['mae_promedio_3_meses_anteriores',MAE_julio_m3,MAE_agosto_m3,MAE_septiembre_m3, MAE_octubre_m3, MAE_noviembre_m3, MAE_diciembre_m3, MAE_enero_m3, MAE_febrero_m3,MAE_marzo_m3],
       ['mae_promedio_4_meses_anteriores',MAE_julio_m4,MAE_agosto_m4,MAE_septiembre_m4, MAE_octubre_m4, MAE_noviembre_m4, MAE_diciembre_m4, MAE_enero_m4, MAE_febrero_m4,MAE_marzo_m4]]
errores_mae = pd.DataFrame(MAE,columns = ['Modelo', 'Error Julio 2018','Error Agosto 2018','Error Septiembre 2018', 'Error Octubre 2018','Error Noviembre 2018', 'Error Diciembre 2018','Error Enero 2019','Error Febrero 2019','Error Marzo 2019'])
errores_mae
# Out:
#                             Modelo  Error Julio 2018  Error Agosto 2018  \
# 0               mae_pedir_anterior          0.138108           0.135469
# 1  mae_promedio_2_meses_anteriores               NaN           0.140563
# 2  mae_promedio_3_meses_anteriores               NaN                NaN
# 3  mae_promedio_4_meses_anteriores               NaN                NaN
#
#    Error Septiembre 2018  Error Octubre 2018  Error Noviembre 2018  \
# 0               0.119700            0.130119              0.148145
# 1               0.125616            0.138270              0.145481
# 2               0.132810            0.147070              0.152375
# 3                    NaN            0.152811              0.161652
#
#    Error Diciembre 2018  Error Enero 2019  Error Febrero 2019  \
# 0              0.177139          0.161523            0.122208
# 1              0.168484          0.158390            0.143794
# 2              0.168346          0.152440            0.153275
# ...

# %% [markdown]
# ### Gráficas

# %% [markdown]
# ### MAE

# %%
MAE = [['Julio',MAE_julio_m1,MAE_julio_m2,MAE_julio_m3,MAE_julio_m4],
       ['Agosto',MAE_agosto_m1,MAE_agosto_m2, MAE_agosto_m3, MAE_agosto_m4],
       ['Septiembre',MAE_septiembre_m1,MAE_septiembre_m2,MAE_septiembre_m3,MAE_septiembre_m4],
       ['Octubre',MAE_octubre_m1, MAE_octubre_m2, MAE_octubre_m3, MAE_octubre_m4],
       ['Noviembre',MAE_noviembre_m1,MAE_noviembre_m2,MAE_noviembre_m3,MAE_noviembre_m4],
       ['Diciembre',MAE_diciembre_m1,MAE_diciembre_m2,MAE_diciembre_m3,MAE_diciembre_m4],
       ['Enero',MAE_enero_m1,MAE_enero_m2,MAE_enero_m3,MAE_enero_m4],
       ['Febrero',MAE_febrero_m1,MAE_febrero_m2,MAE_febrero_m3,MAE_febrero_m4],
       ['Marzo',MAE_marzo_m1,MAE_marzo_m2,MAE_marzo_m3,MAE_marzo_m4]
      ]
errores_mae = pd.DataFrame(MAE,columns = ['Mes', 'mae_pedir_anterior','mae_promedio_2_meses_anteriores','mae_promedio_3_meses_anteriores', 'mae_promedio_4_meses_anteriores'])
errores_mae
# Out:
#           Mes  mae_pedir_anterior  mae_promedio_2_meses_anteriores  \
# 0       Julio            0.138108                              NaN
# 1      Agosto            0.135469                         0.140563
# 2  Septiembre            0.119700                         0.125616
# 3     Octubre            0.130119                         0.138270
# 4   Noviembre            0.148145                         0.145481
# 5   Diciembre            0.177139                         0.168484
# 6       Enero            0.161523                         0.158390
# 7     Febrero            0.122208                         0.143794
# 8       Marzo            0.109561                         0.110653
#
#    mae_promedio_3_meses_anteriores  mae_promedio_4_meses_anteriores
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                         0.132810                              NaN
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.figure(figsize=(20,10))
plt.plot(errores_mae.Mes, errores_mae.mae_pedir_anterior,'o-', color="royalblue")
plt.plot(errores_mae.Mes, errores_mae.mae_promedio_2_meses_anteriores,'o-', color="red")
plt.plot(errores_mae.Mes, errores_mae.mae_promedio_3_meses_anteriores,'o-', color="darkgreen")
plt.plot(errores_mae.Mes, errores_mae.mae_promedio_4_meses_anteriores,'o-', color="darkorange")
plt.ylim(0.09, .20)
plt.legend()
plt.ylabel('MAE')
plt.title('Error Absoluto Total en Modelos Base')
# Out:
# Text(0.5, 1.0, 'Error Absoluto Total en Modelos Base')

# %% [markdown]
# ### MSE

# %%
MSE = [['Julio',MSE_julio_m1,MSE_julio_m2,MSE_julio_m3,MSE_julio_m4],
       ['Agosto',MSE_agosto_m1,MSE_agosto_m2, MSE_agosto_m3, MSE_agosto_m4],
       ['Septiembre',MSE_septiembre_m1,MSE_septiembre_m2,MSE_septiembre_m3,MSE_septiembre_m4],
       ['Octubre',MSE_octubre_m1, MSE_octubre_m2, MSE_octubre_m3, MSE_octubre_m4],
       ['Noviembre',MSE_noviembre_m1,MSE_noviembre_m2,MSE_noviembre_m3,MSE_noviembre_m4],
       ['Diciembre',MSE_diciembre_m1,MSE_diciembre_m2,MSE_diciembre_m3,MSE_diciembre_m4],
       ['Enero',MSE_enero_m1,MSE_enero_m2,MSE_enero_m3,MSE_enero_m4],
       ['Febrero',MSE_febrero_m1,MSE_febrero_m2,MSE_febrero_m3,MSE_febrero_m4],
       ['Marzo',MSE_marzo_m1,MSE_marzo_m2,MSE_marzo_m3,MSE_marzo_m4]
      ]
errores_mse = pd.DataFrame(MSE,columns = ['Mes', 'mse_pedir_anterior','mse_promedio_2_meses_anteriores','mse_promedio_3_meses_anteriores', 'mse_promedio_4_meses_anteriores'])
errores_mse
# Out:
#           Mes  mse_pedir_anterior  mse_promedio_2_meses_anteriores  \
# 0       Julio            0.568659                              NaN
# 1      Agosto            0.515156                         0.551698
# 2  Septiembre            0.392803                         0.364511
# 3     Octubre            0.489997                         0.517241
# 4   Noviembre            0.579640                         0.525178
# 5   Diciembre            0.770711                         0.651252
# 6       Enero            0.696396                         0.552302
# 7     Febrero            0.441374                         0.510564
# 8       Marzo            0.448506                         0.361328
#
#    mse_promedio_3_meses_anteriores  mse_promedio_4_meses_anteriores
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                         0.402212                              NaN
# ...

# %%
plt.figure(figsize=(20,10))
plt.plot(errores_mse.Mes, errores_mse.mse_pedir_anterior,'o-', color="royalblue")
plt.plot(errores_mse.Mes, errores_mse.mse_promedio_2_meses_anteriores,'o-', color="red")
plt.plot(errores_mse.Mes, errores_mse.mse_promedio_3_meses_anteriores,'o-', color="darkgreen")
plt.plot(errores_mse.Mes, errores_mse.mse_promedio_4_meses_anteriores,'o-', color="darkorange")
plt.ylim(0.3, .8)
plt.legend()
plt.ylabel('MSE')
plt.title('Error Cuadrático Medio en Modelos Base')
# Out:
# Text(0.5, 1.0, 'Error Cuadrático Medio en Modelos Base')

# %% [markdown]
# ### RMSE

# %%
RMSE = [['Julio',RMSE_julio_m1,RMSE_julio_m2,RMSE_julio_m3,RMSE_julio_m4],
       ['Agosto',RMSE_agosto_m1,RMSE_agosto_m2, RMSE_agosto_m3, RMSE_agosto_m4],
       ['Septiembre',RMSE_septiembre_m1,RMSE_septiembre_m2,RMSE_septiembre_m3,RMSE_septiembre_m4],
       ['Octubre',RMSE_octubre_m1, RMSE_octubre_m2, RMSE_octubre_m3, RMSE_octubre_m4],
       ['Noviembre',RMSE_noviembre_m1,RMSE_noviembre_m2,RMSE_noviembre_m3,RMSE_noviembre_m4],
       ['Diciembre',RMSE_diciembre_m1,RMSE_diciembre_m2,RMSE_diciembre_m3,RMSE_diciembre_m4],
       ['Enero',RMSE_enero_m1,RMSE_enero_m2,RMSE_enero_m3,RMSE_enero_m4],
       ['Febrero',RMSE_febrero_m1,RMSE_febrero_m2,RMSE_febrero_m3,RMSE_febrero_m4],
       ['Marzo',RMSE_marzo_m1,RMSE_marzo_m2,RMSE_marzo_m3,RMSE_marzo_m4]
      ]
errores_rmse = pd.DataFrame(RMSE,columns = ['Mes', 'rmse_pedir_anterior','rmse_promedio_2_meses_anteriores','rmse_promedio_3_meses_anteriores', 'rmse_promedio_4_meses_anteriores'])
errores_rmse
# Out:
#           Mes  rmse_pedir_anterior  rmse_promedio_2_meses_anteriores  \
# 0       Julio             0.754095                               NaN
# 1      Agosto             0.717744                          0.742764
# 2  Septiembre             0.626740                          0.603748
# 3     Octubre             0.699998                          0.719195
# 4   Noviembre             0.761341                          0.724692
# 5   Diciembre             0.877902                          0.807002
# 6       Enero             0.834503                          0.743170
# 7     Febrero             0.664360                          0.714538
# 8       Marzo             0.669706                          0.601106
#
#    rmse_promedio_3_meses_anteriores  rmse_promedio_4_meses_anteriores
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# ...

# %%
plt.figure(figsize=(20,10))
plt.plot(errores_rmse.Mes, errores_rmse.rmse_pedir_anterior,'o-', color="royalblue")
plt.plot(errores_rmse.Mes, errores_rmse.rmse_promedio_2_meses_anteriores,'o-',color="red")
plt.plot(errores_rmse.Mes, errores_rmse.rmse_promedio_3_meses_anteriores,'o-', color="darkgreen")
plt.plot(errores_rmse.Mes, errores_rmse.rmse_promedio_4_meses_anteriores,'o-', color="darkorange")
plt.ylim(0.5, .9)
plt.legend()
plt.xlabel('Mes')
plt.ylabel('RMSE')
plt.title('Raíz del Error Cuadrático Medio en Modelos Base')
# Out:
# Text(0.5, 1.0, 'Raíz del Error Cuadrático Medio en Modelos Base')

# %%
### Resumen de los resultados

# %%
plt.figure(figsize=(15,12))
plt.subplot(3, 1, 1)
plt.plot(errores_mae.Mes, errores_mae.mae_pedir_anterior,'o-', color="royalblue")
plt.plot(errores_mae.Mes, errores_mae.mae_promedio_2_meses_anteriores,'o-', color="red")
plt.plot(errores_mae.Mes, errores_mae.mae_promedio_3_meses_anteriores,'o-', color="darkgreen")
plt.plot(errores_mae.Mes, errores_mae.mae_promedio_4_meses_anteriores,'o-', color="darkorange")
plt.ylim(0.09, .20)
plt.legend()
plt.ylabel('MAE')
plt.title('Error Absoluto Total en Modelos Base')

plt.subplot(3, 1, 2)
plt.plot(errores_mse.Mes, errores_mse.mse_pedir_anterior,'o-', color="royalblue")
plt.plot(errores_mse.Mes, errores_mse.mse_promedio_2_meses_anteriores,'o-', color="red")
plt.plot(errores_mse.Mes, errores_mse.mse_promedio_3_meses_anteriores,'o-', color="darkgreen")
plt.plot(errores_mse.Mes, errores_mse.mse_promedio_4_meses_anteriores,'o-', color="darkorange")
plt.ylim(0.3, .8)
plt.legend()
plt.ylabel('MSE')
plt.title('Error Cuadrático Medio en Modelos Base')

plt.subplot(3, 1, 3)
plt.plot(errores_rmse.Mes, errores_rmse.rmse_pedir_anterior,'o-', color="royalblue")
plt.plot(errores_rmse.Mes, errores_rmse.rmse_promedio_2_meses_anteriores,'o-',color="red")
plt.plot(errores_rmse.Mes, errores_rmse.rmse_promedio_3_meses_anteriores,'o-', color="darkgreen")
plt.plot(errores_rmse.Mes, errores_rmse.rmse_promedio_4_meses_anteriores,'o-', color="darkorange")
plt.ylim(0.5, .9)
plt.legend()
plt.xlabel('Mes')
plt.ylabel('RMSE')
plt.title('Raíz del Error Cuadrático Medio en Modelos Base')

plt.show()

# %%
plt.figure(figsize=(15,12))
plt.subplot(3, 1, 1)
plt.plot(errores_mae.Mes, errores_mae.mae_pedir_anterior,'o-', color="grey")
plt.plot(errores_mae.Mes, errores_mae.mae_promedio_2_meses_anteriores,'o-', color="red")
plt.plot(errores_mae.Mes, errores_mae.mae_promedio_3_meses_anteriores,'-.', color="grey")
plt.plot(errores_mae.Mes, errores_mae.mae_promedio_4_meses_anteriores,'-', color="grey")
plt.ylim(0.09, .20)
plt.legend()
plt.ylabel('MAE')
plt.title('Error Absoluto Total en Modelos Base')

plt.subplot(3, 1, 2)
plt.plot(errores_mse.Mes, errores_mse.mse_pedir_anterior,'o-', color="grey")
plt.plot(errores_mse.Mes, errores_mse.mse_promedio_2_meses_anteriores,'o-', color="red")
plt.plot(errores_mse.Mes, errores_mse.mse_promedio_3_meses_anteriores,'-.', color="grey")
plt.plot(errores_mse.Mes, errores_mse.mse_promedio_4_meses_anteriores,'-', color="grey")
plt.ylim(0.3, .8)
plt.legend()
plt.ylabel('MSE')
plt.title('Error Cuadrático Medio en Modelos Base')

plt.subplot(3, 1, 3)
plt.plot(errores_rmse.Mes, errores_rmse.rmse_pedir_anterior,'o-',color="grey")
plt.plot(errores_rmse.Mes, errores_rmse.rmse_promedio_2_meses_anteriores,'o-',color="red")
plt.plot(errores_rmse.Mes, errores_rmse.rmse_promedio_3_meses_anteriores,'-.', color="grey")
plt.plot(errores_rmse.Mes, errores_rmse.rmse_promedio_4_meses_anteriores,'-', color="grey")
plt.ylim(0.5, .9)
plt.legend()
plt.xlabel('Mes')
plt.ylabel('RMSE')
plt.title('Raíz del Error Cuadrático Medio en Modelos Base')

plt.show()

# %% [markdown]
# Se puede observar en las tres gráficas que de los modelos bases, los dos que tienen peor desempeño son: pedir el promedio de 3 y 4 meses anteriores. Por ende, lo más probable es que la compañía actualmente este utilizando el modelo de pedir lo del mes anteior o un promedio de los dos meses anterios, con la información proporcionada por la gráfica se asume que la compañía que utiliza el modelo de un promedio de los meses anteriores ddo que su comportamiento es el más estable, es decir, en los meses de diciembre y enero no brinda tan drásticamente en su valor de error.
